# %% [markdown]
# # **Public Transit Schedules**
# This is the first notebook of Exploratory Data Analysis (EDA) on the data of public transit in Tenerife. I will analyse the bus routes, frequencies and timing, visualize them and compare the scheduled and real time performance.
#
# Data sources:
#  - GTFS Schedule: https://datos.tenerife.es/es/datos/conjuntos-de-datos/informacion-sobre-el-sistema-de-transporte-de-titsa-en-tenerife?return=aHR0cHM6Ly9kYXRvcy50ZW5lcmlmZS5lcy9lcy9kYXRvcy9jb25qdW50b3MtZGUtZGF0b3M=
#  - GTFS Realtime: https://transitfeeds.com/p/transportes-interurbanos-de-tenerife/1058
#
# Download date: 10 Sept 2023
#
# Author: Miguel R. Alarcon

# %% [markdown]
# ## Reading data

# %%
import pandas as pd
import os
import numpy as np

import sys
sys.path.append('..')
from utils.gtfs import *

# %% [markdown]
# Creating a dataframe with the stops info and frequency for every segment, i.e., every path joining one stop with other for a specific line id.

# %%
# Read the files from the data folders
Scheduled = GTFSReadFiles('../data/gtfs/scheduled')
Real = GTFSReadFiles('../data/gtfs/real')

# %%
dfs = Scheduled.dfs
Scheduled.info()
# Out:
# agency.txt
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   agency_id        1 non-null      int64
#  1   agency_name      1 non-null      object
#  2   agency_url       1 non-null      object
#  3   agency_timezone  1 non-null      object
#  4   agency_lang      1 non-null      object
#  5   agency_phone     1 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 176.0+ bytes
# None
#
#
# stop_times.txt
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957059 entries, 0 to 957058
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   trip_id         957059 non-null  int64
#  1   arrival_time    957059 non-null  object
#  2   departure_time  957059 non-null  object
#  3   stop_id         957059 non-null  int64
#  4   stop_sequence   957059 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 36.5+ MB
# None
#
#
# calendar_dates.txt
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28376 entries, 0 to 28375
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   service_id      28376 non-null  int64
#  1   date            28376 non-null  int64
#  2   exception_type  28376 non-null  int64
# dtypes: int64(3)
# memory usage: 665.2 KB
# None
#
#
# trips.txt
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34261 entries, 0 to 34260
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   route_id       34261 non-null  int64
#  1   service_id     34261 non-null  int64
#  2   trip_id        34261 non-null  int64
#  3   trip_headsign  34261 non-null  object
#  4   shape_id       34261 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ MB
# None
#
#
# stops.txt
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3779 entries, 0 to 3778
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   stop_id    3779 non-null   int64
#  1   stop_name  3779 non-null   object
#  2   stop_lat   3779 non-null   float64
#  3   stop_lon   3779 non-null   float64
#  4   stop_url   3779 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 147.7+ KB
# None
#
#
# routes.txt
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   route_id          173 non-null    int64
#  1   agency_id         173 non-null    int64
#  2   route_short_name  173 non-null    int64
#  3   route_long_name   173 non-null    object
#  4   route_type        173 non-null    int64
#  5   route_url         173 non-null    object
#  6   route_color       173 non-null    object
#  7   route_text_color  173 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 10.9+ KB
# None

# %%
class GTFSStops:
    
    def __init__(self, dataframes):
        self.dfs = dataframes
        
    def get_positions(self):
        positions_data = self.dfs["stops"][["stop_id", "stop_name", "stop_lat", "stop_lon"]]
        return positions_data
    
    def get_lines(self, stop_id):
        lines = {'route_id': [], 'route_name': [], 'previous_stop': [], 'next_stop': []}
        for trip in self.dfs["stop_times"][self.dfs["stop_times"]["stop_id"] == stop_id].trip_id.values:
            rid = self.dfs["trips"][self.dfs["trips"]["trip_id"] == trip].route_id.values[0]
            if rid not in lines['route_id']:
                lines['route_id'].append(rid)
                rnam = self.dfs["routes"][self.dfs["routes"]["route_id"] == rid].route_short_name.values[0]
                lines['route_name'].append(rnam)
                rst = self.dfs["stop_times"]
                stop_seq_id = rst.loc[(rst["trip_id"] == trip) & (rst["stop_id"] == stop_id)].stop_sequence.values[0]
                prev_stop = rst.loc[(rst["trip_id"] == trip) & (rst["stop_sequence"] == stop_seq_id - 1)].stop_id.values[0]
                next_stop = rst.loc[(rst["trip_id"] == trip) & (rst["stop_sequence"] == stop_seq_id + 1)].stop_id.values[0]
                lines['previous_stop'].append(prev_stop)
                lines['next_stop'].append(next_stop)

        df = pd.DataFrame(lines)
        return df
    
    def get_plot_df(self):
        df = self.get_positions()
        for i in df.index:
            lines = self.get_lines(df.loc[i, 'stop_id'])
            df.iloc[i, 'lines'] = lines['route_name'].values
        return df

# %%
Stops = GTFSStops(dfs)
Stops.get_positions()
# Out:
#       stop_id                 stop_name  stop_lat  stop_lon
# 0        1100                    ACORÁN   28.4184  -16.3038
# 1        1101                   ATABARA   28.4176  -16.3067
# 2        1102                     AYOZE   28.4163  -16.3088
# 3        1103                    ADONAI   28.4152  -16.3113
# 4        1104       POLÍGONO LA CAMPANA   28.4088  -16.3176
# ...       ...                       ...       ...       ...
# 3774     9479          AMÉRICA GONZÁLEZ   28.4803  -16.2564
# 3775     9481         LORENZO DE TOLOSA   28.4694  -16.2787
# 3776     9483        PASEO LA CONCORDIA   28.4648  -16.2522
# 3777     9484             LOS CAMINEROS   28.4952  -16.2163
# 3778     9485  NUESTRA SEÑORA DE LORETO   28.4959  -16.2164
#
# [3779 rows x 4 columns]

# %%
Stops.get_lines(1312)
# Out:
#    route_id  route_name  previous_stop  next_stop
# 0        21          50           1311       1313
# 1        22          51           1311       1926
# 2        33         105           1311       1313

# %%
lines
# Out:
#    route_id  route_name  previous_stop  next_stop
# 0        45         138           1767       1101
# 1         1         139           1767       1101
# 2         4         142           1767       1101
# 3        50         935           1767       1101
# 4         2         940           1767       1101
# 5         3         941           1767       1101

# %%
lines['route_name'].values
# Out:
# array([138, 139, 142, 935, 940, 941])

# %%
Stops.get_lines(df.loc[i, 'stop_id'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/6k/7lpgck413j1__xdr1fy86f9h0000gn/T/ipykernel_8144/391927587.py in <module>
# ----> 1 Stops.get_lines(df.loc[i, 'stop_id'])
#
# /var/folders/6k/7lpgck413j1__xdr1fy86f9h0000gn/T/ipykernel_8144/1887987679.py in get_lines(self, stop_id)
#      19                 stop_seq_id = rst.loc[(rst["trip_id"] == trip) & (rst["stop_id"] == stop_id)].stop_sequence.values[0]
#      20                 prev_stop = rst.loc[(rst["trip_id"] == trip) & (rst["stop_sequence"] == stop_seq_id - 1)].stop_id.values[0]
# ---> 21                 next_stop = rst.loc[(rst["trip_id"] == trip) & (rst["stop_sequence"] == stop_seq_id + 1)].stop_id.values[0]
#      22                 lines['previous_stop'].append(prev_stop)
#      23                 lines['next_stop'].append(next_stop)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df = Stops.get_positions()
for i in df.index:
    lines = Stops.get_lines(df.loc[i, 'stop_id'])
    df.loc[i, 'lines'] = (', ').join(lines['route_name'].values.astype(str))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/6k/7lpgck413j1__xdr1fy86f9h0000gn/T/ipykernel_8144/1292888481.py in <module>
#       1 df = Stops.get_positions()
#       2 for i in df.index:
# ----> 3     lines = Stops.get_lines(df.loc[i, 'stop_id'])
#       4     df.loc[i, 'lines'] = (',').join(lines['route_name'].values.astype(str))
#
# /var/folders/6k/7lpgck413j1__xdr1fy86f9h0000gn/T/ipykernel_8144/1887987679.py in get_lines(self, stop_id)
#      19                 stop_seq_id = rst.loc[(rst["trip_id"] == trip) & (rst["stop_id"] == stop_id)].stop_sequence.values[0]
#      20                 prev_stop = rst.loc[(rst["trip_id"] == trip) & (rst["stop_sequence"] == stop_seq_id - 1)].stop_id.values[0]
# ---> 21                 next_stop = rst.loc[(rst["trip_id"] == trip) & (rst["stop_sequence"] == stop_seq_id + 1)].stop_id.values[0]
#      22                 lines['previous_stop'].append(prev_stop)
#      23                 lines['next_stop'].append(next_stop)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df = Stops.get_plot_df()
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6k/7lpgck413j1__xdr1fy86f9h0000gn/T/ipykernel_8144/3575017716.py in <module>
# ----> 1 df = Stops.get_plot_df()
#       2 df
#
# /var/folders/6k/7lpgck413j1__xdr1fy86f9h0000gn/T/ipykernel_8144/1887987679.py in get_plot_df(self)
#      30         for i in df.index:
#      31             lines = self.get_lines(df.loc[i, 'stop_id'])
# ---> 32             df.iloc[i, 'lines'] = lines['route_name'].values
#      33         return df
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1689         if take_split_path:
#    1690             # We have to operate column-wise
# -> 1691             self._setitem_with_indexer_split_path(indexer, value, name)
#    1692         else:
#    1693             self._setitem_single_block(indexer, value, name)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1773
#    1774             else:
# -> 1775                 raise ValueError(
#    1776                     "Must have equal len keys and value "
#    1777                     "when setting with an iterable"
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
dfs['trips'].loc[dfs['trips']['route_id'] == 105]
# Out:
#        route_id  service_id  trip_id            trip_headsign  shape_id
# 7064        105      194453  6304066  ESTACIÓN LA OROTAVA (T)       410
# 7065        105      194453  6304067  ESTACIÓN LA OROTAVA (T)       410
# 7066        105      194453  6304068  ESTACIÓN LA OROTAVA (T)       410
# 7067        105      194453  6304069  ESTACIÓN LA OROTAVA (T)       410
# 7068        105      194453  6304070  ESTACIÓN LA OROTAVA (T)       410
# ...         ...         ...      ...                      ...       ...
# 25173       105      198488  6447039          LAS DEHESAS (T)       409
# 25174       105      198488  6447040          LAS DEHESAS (T)       409
# 25175       105      198488  6447041          LAS DEHESAS (T)       409
# 25176       105      198488  6447042          LAS DEHESAS (T)       409
# 25177       105      198488  6447043          LAS DEHESAS (T)       411
#
# [86 rows x 5 columns]

# %%
dfs['routes']
# Out:
#      route_id  agency_id  route_short_name  \
# 0         247          2                10
# 1          13          2                11
# 2          14          2                12
# 3          15          2                14
# 4          16          2                15
# ..        ...        ...               ...
# 168       251          2               970
# 169       149          2               971
# 170       150          2               972
# 171       238          2               974
# 172       250          2               975
#
#                                        route_long_name  route_type  \
# 0                 SANTA CRUZ - AEROPUERTO TENERIFE SUR           3
# 1    LA LAGUNA -> EL SAUZAL- POR C/EL CALVARIO DE T...           3
# 2    LA LAGUNA -> EL SAUZAL - POR ZONA CENTRO DE TA...           3
# 3               SANTA CRUZ -> LA LAGUNA(POR LA CUESTA)           3
# 4                      SANTA CRUZ - LA LAGUNA(Express)           3
# ..                                                 ...         ...
# 168                        INTERCAMBIADOR - SAN ANDRÉS           3
# 169    INTERCAMBIADOR - BARRIO SALUD - OFRA (NOCTURNA)           3
# 170  INTERCAMBIADOR - B. SALUD (CUESTA PIEDRA) (NOC...           3
# 171        SANTA CRUZ - SANTA MARÍA - AÑAZA (NOCTURNO)           3
# 172                 SANTA CRUZ - LA GALLEGA (NOCTURNO)           3
#
#                                              route_url route_color  \
# 0    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# 1    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# 2    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# 3    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# 4    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# ..                                                 ...         ...
# 168  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
# 169  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
# 170  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
# 171  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
# 172  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
#
#     route_text_color
# 0             000000
# 1             000000
# 2             000000
# 3             000000
# 4             000000
# ..               ...
# 168           000000
# 169           000000
# 170           000000
# 171           000000
# 172           000000
#
# [173 rows x 8 columns]

# %%
stops = Stops(Scheduled.dataframes)
dfp = stops.get_positions()
dfp.loc[dfp.stop_id == 1312]
# Out:
#      stop_id              stop_name  stop_lat  stop_lon
# 181     1312  TOMÁS GONZÁLEZ RIVERO   28.5342  -16.3606

# %%
stops.get_lines(1312)
# Out:
#    route_id  previous_stop  next_stop
# 0        21           1311       1313
# 1        22           1311       1926
# 2        33           1311       1313

# %%
Quiero tambien una función llamada get_times que dado el stop_id devuelva un df con route_id, date, time, donde date lo obtiene de calendar_dates. Llamando a esta, quiero otra función llamada get_bus_count que, dado el stop_id, date_from y date_to, de el numero de veces que un bus de cada una de las lineas pasa en el intervalo seleccionado. Si date_from y date_to está fuera del intervalo disponible, prieta un warning con los intervalos disponibles.

# %%
stop_times_df.loc[stop_times_df['trip_id'] == 6289828]
# Out:
#    trip_id arrival_time departure_time  stop_id  stop_sequence  stop_id_next
# 0  6289828     05:40:00       05:40:00     9181              1        7118.0
# 1  6289828     05:51:00       05:51:00     7118              2        7134.0
# 2  6289828     06:17:27       06:17:27     7134              3        8185.0
# 3  6289828     06:21:05       06:21:05     8185              4        8326.0
# 4  6289828     06:24:20       06:24:20     8326              5        7571.0
# 5  6289828     06:25:36       06:25:36     7571              6           NaN

# %%
stop_times_df.loc[stop_times_df['service_id'] == 6413738]
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 418359  6413738     17:05:00       17:05:00     4358              1
# 418360  6413738     17:05:51       17:05:51     4360              2
# 418361  6413738     17:06:29       17:06:29     4359              3
# 418362  6413738     17:08:05       17:08:05     4361              4
# 418363  6413738     17:08:46       17:08:46     4362              5
# 418364  6413738     17:09:23       17:09:23     4363              6
# 418365  6413738     17:09:57       17:09:57     4364              7
# 418366  6413738     17:10:41       17:10:41     4365              8
# 418367  6413738     17:11:45       17:11:45     4366              9
# 418368  6413738     17:12:39       17:12:39     4367             10
# 418369  6413738     17:13:08       17:13:08     4368             11
# 418370  6413738     17:13:56       17:13:56     4369             12
# 418371  6413738     17:15:26       17:15:26     4348             13
# 418372  6413738     17:16:53       17:16:53     5163             14
# 418373  6413738     17:20:19       17:20:19     4349             15
# 418374  6413738     17:20:41       17:20:41     4350             16
# 418375  6413738     17:22:08       17:22:08     4351             17
# 418376  6413738     17:23:16       17:23:16     4352             18
# 418377  6413738     17:23:56       17:23:56     4353             19
# 418378  6413738     17:24:29       17:24:29     4354             20
# 418379  6413738     17:25:40       17:25:40     4355             21
# 418380  6413738     17:27:22       17:27:22     4356             22
# 418381  6413738     17:28:28       17:28:28     4357             23
# 418382  6413738     17:29:24       17:29:24     4358             24
#
#         stop_id_next
# 418359        4360.0
# 418360        4359.0
# 418361        4361.0
# 418362        4362.0
# 418363        4363.0
# 418364        4364.0
# 418365        4365.0
# 418366        4366.0
# 418367        4367.0
# 418368        4368.0
# 418369        4369.0
# 418370        4348.0
# 418371        5163.0
# 418372        4349.0
# 418373        4350.0
# 418374        4351.0
# 418375        4352.0
# 418376        4353.0
# 418377        4354.0
# 418378        4355.0
# 418379        4356.0
# 418380        4357.0
# 418381        4358.0
# 418382           NaN

# %%
# Merge trips_df and calendar_dates_df on service_id to obtain a relation between trip_id and date
trip_dates_simple_df = trips_df[['trip_id', 'service_id']].merge(calendar_dates_df[['service_id', 'date']], on='service_id', how='left')

# Drop the service_id column as it's no longer needed
trip_dates_simple_df = trip_dates_simple_df.drop(columns=['service_id'])

# Display the resulting dataframe
trip_dates_simple_df
# Out:
#         trip_id      date
# 0       6289828  20230917
# 1       6289828  20230924
# 2       6289828  20231001
# 3       6289828  20231008
# 4       6289828  20231012
# ...         ...       ...
# 928358  6456126  20230831
# 928359  6456126  20230904
# 928360  6456126  20230905
# 928361  6456126  20230906
# 928362  6456126  20230907
#
# [928363 rows x 2 columns]

# %%
trips_df.loc[trips_df['service_id'] == 197466]
# Out:
#        route_id  service_id  trip_id      trip_headsign  shape_id
# 15087       128      197466  6413728  ESTACIÓN ICOD (T)      2383
# 15088       128      197466  6413729  ESTACIÓN ICOD (T)      2383
# 15089       128      197466  6413730  ESTACIÓN ICOD (T)      2383
# 15090       128      197466  6413731  ESTACIÓN ICOD (T)      2383
# 15091       128      197466  6413732  ESTACIÓN ICOD (T)      2383
# 15092       128      197466  6413733  ESTACIÓN ICOD (T)      2383
# 15093       128      197466  6413734  ESTACIÓN ICOD (T)      2383
# 15094       128      197466  6413735  ESTACIÓN ICOD (T)      2383
# 15095       128      197466  6413736  ESTACIÓN ICOD (T)      2383
# 15096       128      197466  6413737  ESTACIÓN ICOD (T)      2383
# 15097       128      197466  6413738  ESTACIÓN ICOD (T)      2383
# 15098       128      197466  6413739  ESTACIÓN ICOD (T)      2383
# 15099       128      197466  6413740  ESTACIÓN ICOD (T)      2383

# %%
# Read the GTFS files into dataframes
files_path = '../data/gtfs/planned/GTFS_Expected'
stop_times_df = pd.read_csv(os.path.join(files_path, 'stop_times.txt'))
stops_df = pd.read_csv(os.path.join(files_path, 'stops.txt'))
trips_df = pd.read_csv(os.path.join(files_path, 'trips.txt'))
routes_df = pd.read_csv(os.path.join(files_path, 'routes.txt'))
calendar_dates_df = pd.read_csv(os.path.join(files_path, 'calendar_dates.txt'))

# Create segments
stop_times_df['stop_id_next'] = stop_times_df.groupby('trip_id')['stop_id'].shift(-1)
segments_df = stop_times_df.dropna(subset=['stop_id_next'])
segments_df['stop_id_next'] = segments_df['stop_id_next'].astype(int)
segments_df = segments_df.merge(stops_df[['stop_id', 'stop_lat', 'stop_lon']], on='stop_id')
segments_df = segments_df.merge(stops_df[['stop_id', 'stop_lat', 'stop_lon']],
                                left_on='stop_id_next', right_on='stop_id', suffixes=('', '_next'))

segments_df = segments_df.merge(trips_df, on='trip_id', how='left')
segments_df = segments_df.merge(calendar_dates_df, on='service_id', how='left')


#segments_df = segments_df.drop(columns=['stop_id_next', 'stop_sequence'])
segments_df['frequency'] = segments_df.groupby(['stop_id', 'stop_lat_next', 'stop_lon_next']).transform('count')['trip_id']

segments_df = segments_df.loc[:,~segments_df.columns.duplicated()].copy()
segments_df = segments_df.drop(columns=['departure_time', 'stop_sequence'])


# Now merge segments_df with trip_dates_df on trip_id to add the date column
segments_df = segments_df.merge(trips_df, on='trip_id', how='left')




print(segments_df.info())
segments_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6k/7lpgck413j1__xdr1fy86f9h0000gn/T/ipykernel_13145/3335148086.py in <module>
#      20
#      21 #segments_df = segments_df.drop(columns=['stop_id_next', 'stop_sequence'])
# ---> 22 segments_df['frequency'] = segments_df.groupby(['stop_id', 'stop_lat_next', 'stop_lon_next']).transform('count')['trip_id']
#      23
#      24 segments_df = segments_df.loc[:,~segments_df.columns.duplicated()].copy()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    1182     @Appender(_transform_template)
#    1183     def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1184         return self._transform(
#    1185             func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#    1186         )
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    1658             # Temporarily set observed for dealing with categoricals.
#    1659             with com.temp_setattr(self, "observed", True):
# -> 1660                 result = getattr(self, func)(*args, **kwargs)
#    1661
#    1662             if self._can_use_transform_fast(result):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in count(self)
#    1870             return counted
#    1871
# -> 1872         new_mgr = data.grouped_reduce(hfunc)
#    1873
#    1874         # If we are grouping on categoricals we want unobserved categories to
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in grouped_reduce(self, func, ignore_failures)
#    1346                 for sb in blk._split():
#    1347                     try:
# -> 1348                         applied = sb.apply(func)
#    1349                     except (TypeError, NotImplementedError):
#    1350                         if not ignore_failures:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     400         one
#     401         """
# --> 402         result = func(self.values, **kwargs)
#     403
#     404         return self._split_op_result(result)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in hfunc(bvalues)
#    1861                 masked = mask & ~isna(bvalues).reshape(1, -1)
#    1862             else:
# -> 1863                 masked = mask & ~isna(bvalues)
#    1864
#    1865             counted = lib.count_level_2d(masked, labels=ids, max_bin=ngroups, axis=1)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     142     Name: 1, dtype: bool
#     143     """
# --> 144     return _isna(obj)
#     145
#     146
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna(obj, inf_as_na)
#     171         return False
#     172     elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 173         return _isna_array(obj, inf_as_na=inf_as_na)
#     174     elif isinstance(obj, ABCIndex):
#     175         # Try to use cached isna, which also short-circuits for integer dtypes
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna_array(values, inf_as_na)
#     253             result = values.isna()  # type: ignore[assignment]
#     254     elif is_string_or_object_np_dtype(values.dtype):
# --> 255         result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     256     elif needs_i8_conversion(dtype):
#     257         # this is the NaT pattern
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna_string_dtype(values, inf_as_na)
#     277             result = libmissing.isnaobj(values, inf_as_na=inf_as_na)
#     278         elif values.ndim == 2:
# --> 279             result = libmissing.isnaobj2d(values, inf_as_na=inf_as_na)
#     280         else:
#     281             # 0-D, reached via e.g. mask_missing
#
# KeyboardInterrupt:

# %%
segments_df
# Out:
#           trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0         6289828     05:40:00       05:40:00     9181              1
# 1         6289828     05:40:00       05:40:00     9181              1
# 2         6289828     05:40:00       05:40:00     9181              1
# 3         6289828     05:40:00       05:40:00     9181              1
# 4         6289828     05:40:00       05:40:00     9181              1
# ...           ...          ...            ...      ...            ...
# 25356462  6455984     16:45:00       16:45:00     9478              1
# 25356463  6455985     18:00:00       18:00:00     9478              1
# 25356464  6455985     18:00:00       18:00:00     9478              1
# 25356465  6455986     18:50:00       18:50:00     9478              1
# 25356466  6455986     18:50:00       18:50:00     9478              1
#
#           stop_id_next  stop_lat  stop_lon  stop_id_next  stop_lat_next  \
# 0                 7118   28.4590  -16.2527          7118         28.382
# 1                 7118   28.4590  -16.2527          7118         28.382
# 2                 7118   28.4590  -16.2527          7118         28.382
# 3                 7118   28.4590  -16.2527          7118         28.382
# 4                 7118   28.4590  -16.2527          7118         28.382
# ...                ...       ...       ...           ...            ...
# 25356462          9477   28.5739  -16.1878          9477         28.572
# 25356463          9477   28.5739  -16.1878          9477         28.572
# 25356464          9477   28.5739  -16.1878          9477         28.572
# 25356465          9477   28.5739  -16.1878          9477         28.572
# 25356466          9477   28.5739  -16.1878          9477         28.572
#
#           stop_lon_next  route_id  service_id                trip_headsign  \
# 0              -16.3634       247      193969  AEROPUERTO TENERIFE SUR (T)
# 1              -16.3634       247      193969  AEROPUERTO TENERIFE SUR (T)
# 2              -16.3634       247      193969  AEROPUERTO TENERIFE SUR (T)
# 3              -16.3634       247      193969  AEROPUERTO TENERIFE SUR (T)
# 4              -16.3634       247      193969  AEROPUERTO TENERIFE SUR (T)
# ...                 ...       ...         ...                          ...
# 25356462       -16.1923       239      198735                   BAJO ASANO
# 25356463       -16.1923       239      198735                   BAJO ASANO
# 25356464       -16.1923       239      198735                   BAJO ASANO
# 25356465       -16.1923       239      198735                   BAJO ASANO
# 25356466       -16.1923       239      198735                   BAJO ASANO
#
#           shape_id      date  exception_type
# 0             2640  20230917               1
# 1             2640  20230924               1
# 2             2640  20231001               1
# 3             2640  20231008               1
# 4             2640  20231012               1
# ...            ...       ...             ...
# 25356462      2323  20230909               1
# 25356463      2323  20230902               1
# 25356464      2323  20230909               1
# 25356465      2323  20230902               1
# 25356466      2323  20230909               1
#
# [25356467 rows x 17 columns]

# %%
# Compute the frequency for each segment
segments_df['frequency'] = segments_df.groupby(['stop_id', 'stop_lat_next', 'stop_lon_next']).transform('count')['trip_id']

# Display the segments dataframe with frequency
segments_df.head()
# Out:
# INFO:root:Reading "routes.txt".
# INFO:root:Reading "stops.txt".
# INFO:root:Reading "shapes.txt".
# INFO:root:Reading "stop_times.txt".
# INFO:root:get trips in stop_times
# INFO:root:accessing trips
# INFO:root:Reading "trips.txt".
# INFO:root:File "calendar.txt" not found.
# INFO:root:Reading "calendar_dates.txt".
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6k/7lpgck413j1__xdr1fy86f9h0000gn/T/ipykernel_13145/2226604794.py in <module>
#      11 # stop_times = feed.stop_times
#      12 shapes = feed.shapes
# ---> 13 segments_gdf = feed.segments
#
# /opt/anaconda3/lib/python3.9/site-packages/gtfs_functions/gtfs_functions.py in segments(self)
#     208     def segments(self):
#     209         if self._segments is None:
# --> 210             self._segments = self.get_segments()
#     211
#     212         return self._segments
#
# /opt/anaconda3/lib/python3.9/site-packages/gtfs_functions/gtfs_functions.py in get_segments(self)
#     745         Returns the segment geometry as well as additional segment information
#     746         """
# --> 747         stop_times = self.stop_times
#     748         shapes = self.shapes
#     749
#
# /opt/anaconda3/lib/python3.9/site-packages/gtfs_functions/gtfs_functions.py in stop_times(self)
#     180     def stop_times(self):
#     181         if self._stop_times is None:
# --> 182             self._stop_times = self.get_stop_times()
#     183
#     184         return self._stop_times
#
# /opt/anaconda3/lib/python3.9/site-packages/gtfs_functions/gtfs_functions.py in get_stop_times(self)
#     593         else:
#     594             logging.info('get trips in stop_times')
# --> 595             trips = self.trips
#     596         stops = self.stops
#     597
#
# /opt/anaconda3/lib/python3.9/site-packages/gtfs_functions/gtfs_functions.py in trips(self)
#     150         logging.info('accessing trips')
#     151         if self._trips is None:
# --> 152             self._trips = self.get_trips()
#     153
#     154         if self._patterns and self._trips_patterns is None:
#
# /opt/anaconda3/lib/python3.9/site-packages/gtfs_functions/gtfs_functions.py in get_trips(self)
#     506                 the "dates" variable at all.
#     507             """
# --> 508             dates_service_id = self.parse_calendar()
#     509
#     510             # If busiest_date=True, we have to count the number of trips
#
# /opt/anaconda3/lib/python3.9/site-packages/gtfs_functions/gtfs_functions.py in parse_calendar(self)
#     395
#     396         # Parse dates
# --> 397         calendar['start_date_dt'] = calendar.start_date.astype(str).apply(pl.parse)
#     398         calendar['end_date_dt'] = calendar.end_date.astype(str).apply(pl.parse)
#     399
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'start_date'

# %%
# Load an empty map
from keplergl import KeplerGl
map_1 = KeplerGl()
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()

# %%
routes
# Out:
#     route_id  agency_id route_short_name  \
# 0        247          2               10
# 1         13          2               11
# 2         14          2               12
# 3         15          2               14
# 4         16          2               15
# ..       ...        ...              ...
# 168      251          2              970
# 169      149          2              971
# 170      150          2              972
# 171      238          2              974
# 172      250          2              975
#
#                                        route_long_name  route_type  \
# 0                 SANTA CRUZ - AEROPUERTO TENERIFE SUR           3
# 1    LA LAGUNA -> EL SAUZAL- POR C/EL CALVARIO DE T...           3
# 2    LA LAGUNA -> EL SAUZAL - POR ZONA CENTRO DE TA...           3
# 3               SANTA CRUZ -> LA LAGUNA(POR LA CUESTA)           3
# 4                      SANTA CRUZ - LA LAGUNA(Express)           3
# ..                                                 ...         ...
# 168                        INTERCAMBIADOR - SAN ANDRÉS           3
# 169    INTERCAMBIADOR - BARRIO SALUD - OFRA (NOCTURNA)           3
# 170  INTERCAMBIADOR - B. SALUD (CUESTA PIEDRA) (NOC...           3
# 171        SANTA CRUZ - SANTA MARÍA - AÑAZA (NOCTURNO)           3
# 172                 SANTA CRUZ - LA GALLEGA (NOCTURNO)           3
#
#                                              route_url route_color  \
# 0    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# 1    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# 2    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# 3    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# 4    http://www.titsa.com/index.php/tus-guaguas/lin...      75AD1C
# ..                                                 ...         ...
# 168  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
# 169  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
# 170  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
# 171  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
# 172  http://www.titsa.com/index.php/tus-guaguas/lin...      3F8FCF
#
#     route_text_color
# 0             000000
# 1             000000
# 2             000000
# 3             000000
# 4             000000
# ..               ...
# 168           000000
# 169           000000
# 170           000000
# 171           000000
# 172           000000
#
# [173 rows x 8 columns]
