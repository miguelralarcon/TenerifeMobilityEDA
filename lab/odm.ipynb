# %% [markdown]
# # User Origin-Destination Pattern
#
# This is the first notebook of Exploratory Data Analysis (EDA) on the data of user origin-destination patterns using public transportation in Tenerife.
#
# Data source: https://portaldetransparencia.titsa.com/index.php/76-estadisticas/482-open-data
#
# Data download date: 10 Sept 2023
#
# Author: Miguel R. Alarcon

# %%
import os
from glob import glob
import numpy as np
import pandas as pd

# %% [markdown]
# Let's check the available data of ODs during working days of June 2023

# %%
odm_file_path = '../data/odm/23_06/MOD_TP_JUNIO_LAB/MOD_TP_JUNIO_LAB.csv'
df = pd.read_csv(odm_file_path, sep=';')

print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1910572 entries, 0 to 1910571
# Data columns (total 10 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   ID_LINEA_VIAJE_ACTUAL           int64
#  1   ID_PRODUCTO_CODIGO              int64
#  2   HORA_VIAJE_ACTUAL               int64
#  3   ID_PARADA_ENTRADA_VIAJE_ACTUAL  int64
#  4   ID_PARADA_SALIDA_VIAJE_ACTUAL   float64
#  5   PASAJEROS_TOTAL                 int64
#  6   TOTAL_FECHAS_CALCULADAS         int64
#  7   ID_LINEA_VIAJE_SIGUIENTE        int64
#  8   ID_LINEA_VIAJE_ANTERIOR         int64
#  9   ID_MATRIZ                       object
# dtypes: float64(1), int64(8), object(1)
# memory usage: 145.8+ MB
# None
#    ID_LINEA_VIAJE_ACTUAL  ID_PRODUCTO_CODIGO  HORA_VIAJE_ACTUAL  \
# 0                    408                  76                 22
# 1                     51                  77                 11
# ...

# %% [markdown]
# For proper visualization, th

# %%
df.loc[df.ID_LINEA_VIAJE_ACTUAL == 51]
# Out:
#          ID_LINEA_VIAJE_ACTUAL  ID_PRODUCTO_CODIGO  HORA_VIAJE_ACTUAL  \
# 1                           51                  77                 11
# 2                           51                  77                 22
# 9                           51                  77                 18
# 19                          51                  76                 14
# 41                          51                 170                 10
# ...                        ...                 ...                ...
# 1910481                     51                  76                 16
# 1910497                     51                 200                 10
# 1910514                     51                 170                 17
# 1910519                     51                 200                 21
# 1910557                     51                  76                 18
#
#          ID_PARADA_ENTRADA_VIAJE_ACTUAL  ID_PARADA_SALIDA_VIAJE_ACTUAL  \
# ...
